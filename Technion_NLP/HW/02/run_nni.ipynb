# %%
search_space = {
    "batch_size": {"_type":"choice", "_value": [16, 32, 64, 128]},
    "hidden_size":{"_type":"choice","_value":[128, 256, 512, 1024]},
    "lr":{"_type":"choice","_value":[0.0001, 0.001, 0.01, 0.1]},
    "momentum":{"_type":"uniform","_value":[0, 1]}
}

# %%
from nni.experiment import Experiment
experiment = Experiment('local')
experiment.config.experiment_name = "test"
experiment.config.search_space = search_space
experiment.config.trial_command = "python3 main.py"
experiment.config.trial_code_directory = "./"
experiment.config.trial_concurrency = 1

experiment.config.tuner.name = "TPE"

# %%
experiment.run(8077)
# Out:
# [2022-06-30 07:58:05] Creating experiment, Experiment ID: 1pniy78u
# [2022-06-30 07:58:05] Starting web server...
# [2022-06-30 07:58:06] Setting up...
# [2022-06-30 07:58:06] Web portal URLs: http://127.0.0.1:8077 http://10.53.140.144:8077 http://172.17.0.1:8077 http://172.21.0.1:8077
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /usr/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File /usr/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f0443c3a040>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/git/courses/venv/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/git/courses/venv/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=8077): Max retries exceeded with url: /api/v1/nni/check-status (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f0443c3a040>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 experiment.run(8077)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:183, in Experiment.run(self, port, wait_completion, debug)
#     181 if wait_completion:
#     182     try:
# --> 183         self._wait_completion()
#     184     except KeyboardInterrupt:
#     185         _logger.warning('KeyboardInterrupt detected')
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:163, in Experiment._wait_completion(self)
#     161 def _wait_completion(self) -> bool:
#     162     while True:
# --> 163         status = self.get_status()
#     164         if status == 'DONE' or status == 'STOPPED':
#     165             return True
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:283, in Experiment.get_status(self)
#     274 def get_status(self) -> str:
#     275     """
#     276     Return experiment status as a str.
#     277
#    (...)
#     281         Experiment status.
#     282     """
# --> 283     resp = rest.get(self.port, '/check-status', self.url_prefix)
#     284     return resp['status']
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/rest.py:43, in get(port, api, prefix)
#      42 def get(port: Optional[int], api: str, prefix: Optional[str] = None) -> Any:
# ---> 43     return request('get', port, api, prefix=prefix)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/rest.py:31, in request(method, port, api, data, prefix)
#      28 url = '/'.join(part.strip('/') for part in url_parts if part)
#      30 if data is None:
# ---> 31     resp = requests.request(method, url, timeout=timeout)
#      32 else:
#      33     resp = requests.request(method, url, json=data, timeout=timeout)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/git/courses/venv/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/git/courses/venv/lib/python3.8/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=8077): Max retries exceeded with url: /api/v1/nni/check-status (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f0443c3a040>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
experiment.run(8077)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 experiment.run(8077)
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:180, in Experiment.run(self, port, wait_completion, debug)
#     170 def run(self, port: int = 8080, wait_completion: bool = True, debug: bool = False) -> bool | None:
#     171     """
#     172     Run the experiment.
#     173
#    (...)
#     178     Else if ``wait_completion`` is ``False``, this function will non-block and return None immediately.
#     179     """
# --> 180     self.start(port, debug)
#     181     if wait_completion:
#     182         try:
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:135, in Experiment.start(self, port, debug, run_mode)
#     119 def start(self, port: int = 8080, debug: bool = False, run_mode: RunMode = RunMode.Background) -> None:
#     120     """
#     121     Start the experiment in background.
#     122
#    (...)
#     133         Running the experiment in foreground or background
#     134     """
# --> 135     self._start_impl(port, debug, run_mode, None, [])
#
# File ~/git/courses/venv/lib/python3.8/site-packages/nni/experiment/experiment.py:98, in Experiment._start_impl(self, port, debug, run_mode, tuner_command_channel, tags)
#      95 if config.use_annotation:
#      96     raise RuntimeError('NNI annotation is not supported by Python experiment API.')
# ---> 98 log_file = Path(config.experiment_working_directory, self.id, 'log', 'experiment.log')
#      99 log_file.parent.mkdir(parents=True, exist_ok=True)
#     100 log_level = 'debug' if (debug or config.log_level == 'trace') else config.log_level
#
# File /usr/lib/python3.8/pathlib.py:1042, in Path.__new__(cls, *args, **kwargs)
#    1040 if cls is Path:
#    1041     cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1042 self = cls._from_parts(args, init=False)
#    1043 if not self._flavour.is_supported:
#    1044     raise NotImplementedError("cannot instantiate %r on your system"
#    1045                               % (cls.__name__,))
#
# File /usr/lib/python3.8/pathlib.py:683, in PurePath._from_parts(cls, args, init)
#     678 @classmethod
#     679 def _from_parts(cls, args, init=True):
#     680     # We need to call _parse_args on the instance, so as to get the
#     681     # right flavour.
#     682     self = object.__new__(cls)
# --> 683     drv, root, parts = self._parse_args(args)
#     684     self._drv = drv
#     685     self._root = root
#
# File /usr/lib/python3.8/pathlib.py:667, in PurePath._parse_args(cls, args)
#     665     parts += a._parts
#     666 else:
# --> 667     a = os.fspath(a)
#     668     if isinstance(a, str):
#     669         # Force-cast str subclasses to str (issue #21127)
#     670         parts.append(str(a))
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
